// %% [markdown]
// # Sampling Fraction

// %%
TFile *f=new TFile("histSF_fccee_inclined_90.root");

// %%
f->ls();
// Out:
// TFile**		histSF_fccee_inclined_90.root
//  TFile*		histSF_fccee_inclined_90.root
//   KEY: TH1F	ecal_totalEnergy_layer0;1	Total deposited energy in layer 0
//   KEY: TH1F	ecal_activeEnergy_layer0;1	Deposited energy in active material, in layer 0
//   KEY: TH1F	ecal_sf_layer0;1	SF for layer 0
//   KEY: TH1F	ecal_totalEnergy_layer1;1	Total deposited energy in layer 1
//   KEY: TH1F	ecal_activeEnergy_layer1;1	Deposited energy in active material, in layer 1
//   KEY: TH1F	ecal_sf_layer1;1	SF for layer 1
//   KEY: TH1F	ecal_totalEnergy_layer2;1	Total deposited energy in layer 2
//   KEY: TH1F	ecal_activeEnergy_layer2;1	Deposited energy in active material, in layer 2
//   KEY: TH1F	ecal_sf_layer2;1	SF for layer 2
//   KEY: TH1F	ecal_totalEnergy_layer3;1	Total deposited energy in layer 3
//   KEY: TH1F	ecal_activeEnergy_layer3;1	Deposited energy in active material, in layer 3
//   KEY: TH1F	ecal_sf_layer3;1	SF for layer 3
//   KEY: TH1F	ecal_totalEnergy_layer4;1	Total deposited energy in layer 4
//   KEY: TH1F	ecal_activeEnergy_layer4;1	Deposited energy in active material, in layer 4
//   KEY: TH1F	ecal_sf_layer4;1	SF for layer 4
//   KEY: TH1F	ecal_totalEnergy_layer5;1	Total deposited energy in layer 5
//   KEY: TH1F	ecal_activeEnergy_layer5;1	Deposited energy in active material, in layer 5
//   KEY: TH1F	ecal_sf_layer5;1	SF for layer 5
//   KEY: TH1F	ecal_totalEnergy_layer6;1	Total deposited energy in layer 6
//   KEY: TH1F	ecal_activeEnergy_layer6;1	Deposited energy in active material, in layer 6
//   KEY: TH1F	ecal_sf_layer6;1	SF for layer 6
//   KEY: TH1F	ecal_totalEnergy_layer7;1	Total deposited energy in layer 7
//   KEY: TH1F	ecal_activeEnergy_layer7;1	Deposited energy in active material, in layer 7
//   KEY: TH1F	ecal_sf_layer7;1	SF for layer 7
//   KEY: TH1F	ecal_totalEnergy_layer8;1	Total deposited energy in layer 8
//   KEY: TH1F	ecal_activeEnergy_layer8;1	Deposited energy in active material, in layer 8
//   KEY: TH1F	ecal_sf_layer8;1	SF for layer 8
//   KEY: TH1F	ecal_totalEnergy_layer9;1	Total deposited energy in layer 9
//   KEY: TH1F	ecal_activeEnergy_layer9;1	Deposited energy in active material, in layer 9
//   KEY: TH1F	ecal_sf_layer9;1	SF for layer 9
//   KEY: TH1F	ecal_totalEnergy_layer10;1	Total deposited energy in layer 10
//   KEY: TH1F	ecal_activeEnergy_layer10;1	Deposited energy in active material, in layer 10
//   KEY: TH1F	ecal_sf_layer10;1	SF for layer 10
//   KEY: TH1F	ecal_totalEnergy_layer11;1	Total deposited energy in layer 11
//   KEY: TH1F	ecal_activeEnergy_layer11;1	Deposited energy in active material, in layer 11
//   KEY: TH1F	ecal_sf_layer11;1	SF for layer 11
//   KEY: TH1F	ecal_totalEnergy_layer12;1	Total deposited energy in layer 12
//   KEY: TH1F	ecal_activeEnergy_layer12;1	Deposited energy in active material, in layer 12
//   KEY: TH1F	ecal_sf_layer12;1	SF for layer 12
//   KEY: TH1F	ecal_totalEnergy_layer13;1	Total deposited energy in layer 13
//   KEY: TH1F	ecal_activeEnergy_layer13;1	Deposited energy in active material, in layer 13
//   KEY: TH1F	ecal_sf_layer13;1	SF for layer 13
//   KEY: TH1F	ecal_totalEnergy_layer14;1	Total deposited energy in layer 14
//   KEY: TH1F	ecal_activeEnergy_layer14;1	Deposited energy in active material, in layer 14
//   KEY: TH1F	ecal_sf_layer14;1	SF for layer 14
//   KEY: TH1F	ecal_totalEnergy_layer15;1	Total deposited energy in layer 15
//   KEY: TH1F	ecal_activeEnergy_layer15;1	Deposited energy in active material, in layer 15
//   KEY: TH1F	ecal_sf_layer15;1	SF for layer 15
//   KEY: TH1F	ecal_totalEnergy_layer16;1	Total deposited energy in layer 16
//   KEY: TH1F	ecal_activeEnergy_layer16;1	Deposited energy in active material, in layer 16
//   KEY: TH1F	ecal_sf_layer16;1	SF for layer 16
//   KEY: TH1F	ecal_totalEnergy_layer17;1	Total deposited energy in layer 17
//   KEY: TH1F	ecal_activeEnergy_layer17;1	Deposited energy in active material, in layer 17
//   KEY: TH1F	ecal_sf_layer17;1	SF for layer 17
//   KEY: TH1F	ecal_totalEnergy_layer18;1	Total deposited energy in layer 18
//   KEY: TH1F	ecal_activeEnergy_layer18;1	Deposited energy in active material, in layer 18
//   KEY: TH1F	ecal_sf_layer18;1	SF for layer 18
//   KEY: TH1F	ecal_totalEnergy_layer19;1	Total deposited energy in layer 19
//   KEY: TH1F	ecal_activeEnergy_layer19;1	Deposited energy in active material, in layer 19
//   KEY: TH1F	ecal_sf_layer19;1	SF for layer 19
//   KEY: TH1F	ecal_totalEnergy_layer20;1	Total deposited energy in layer 20
//   KEY: TH1F	ecal_activeEnergy_layer20;1	Deposited energy in active material, in layer 20
//   KEY: TH1F	ecal_sf_layer20;1	SF for layer 20
//   KEY: TH1F	ecal_totalEnergy_layer21;1	Total deposited energy in layer 21
//   KEY: TH1F	ecal_activeEnergy_layer21;1	Deposited energy in active material, in layer 21
//   KEY: TH1F	ecal_sf_layer21;1	SF for layer 21
//   KEY: TH1F	ecal_totalEnergy_layer22;1	Total deposited energy in layer 22
//   KEY: TH1F	ecal_activeEnergy_layer22;1	Deposited energy in active material, in layer 22
//   KEY: TH1F	ecal_sf_layer22;1	SF for layer 22
//   KEY: TH1F	ecal_totalEnergy_layer23;1	Total deposited energy in layer 23
//   KEY: TH1F	ecal_activeEnergy_layer23;1	Deposited energy in active material, in layer 23
//   KEY: TH1F	ecal_sf_layer23;1	SF for layer 23
//   KEY: TH1F	ecal_totalEnergy_layer24;1	Total deposited energy in layer 24
//   KEY: TH1F	ecal_activeEnergy_layer24;1	Deposited energy in active material, in layer 24
//   KEY: TH1F	ecal_sf_layer24;1	SF for layer 24
//   KEY: TH1F	ecal_totalEnergy_layer25;1	Total deposited energy in layer 25
//   KEY: TH1F	ecal_activeEnergy_layer25;1	Deposited energy in active material, in layer 25
//   KEY: TH1F	ecal_sf_layer25;1	SF for layer 25
//   KEY: TH1F	ecal_totalEnergy_layer26;1	Total deposited energy in layer 26
//   KEY: TH1F	ecal_activeEnergy_layer26;1	Deposited energy in active material, in layer 26
//   KEY: TH1F	ecal_sf_layer26;1	SF for layer 26
//   KEY: TH1F	ecal_totalEnergy_layer27;1	Total deposited energy in layer 27
//   KEY: TH1F	ecal_activeEnergy_layer27;1	Deposited energy in active material, in layer 27
//   KEY: TH1F	ecal_sf_layer27;1	SF for layer 27
//   KEY: TH1F	ecal_totalEnergy_layer28;1	Total deposited energy in layer 28
//   KEY: TH1F	ecal_activeEnergy_layer28;1	Deposited energy in active material, in layer 28
//   KEY: TH1F	ecal_sf_layer28;1	SF for layer 28
//   KEY: TH1F	ecal_totalEnergy_layer29;1	Total deposited energy in layer 29
//   KEY: TH1F	ecal_activeEnergy_layer29;1	Deposited energy in active material, in layer 29
//   KEY: TH1F	ecal_sf_layer29;1	SF for layer 29
//   KEY: TH1F	ecal_totalEnergy_layer30;1	Total deposited energy in layer 30
//   KEY: TH1F	ecal_activeEnergy_layer30;1	Deposited energy in active material, in layer 30
//   KEY: TH1F	ecal_sf_layer30;1	SF for layer 30
//   KEY: TH1F	ecal_totalEnergy_layer31;1	Total deposited energy in layer 31
//   KEY: TH1F	ecal_activeEnergy_layer31;1	Deposited energy in active material, in layer 31
//   KEY: TH1F	ecal_sf_layer31;1	SF for layer 31
//   KEY: TH1F	ecal_totalEnergy_layer32;1	Total deposited energy in layer 32
//   KEY: TH1F	ecal_activeEnergy_layer32;1	Deposited energy in active material, in layer 32
//   KEY: TH1F	ecal_sf_layer32;1	SF for layer 32
//   KEY: TH1F	ecal_totalEnergy_layer33;1	Total deposited energy in layer 33
//   KEY: TH1F	ecal_activeEnergy_layer33;1	Deposited energy in active material, in layer 33
//   KEY: TH1F	ecal_sf_layer33;1	SF for layer 33
//   KEY: TH1F	ecal_totalEnergy_layer34;1	Total deposited energy in layer 34
//   KEY: TH1F	ecal_activeEnergy_layer34;1	Deposited energy in active material, in layer 34
//   KEY: TH1F	ecal_sf_layer34;1	SF for layer 34
//   KEY: TH1F	ecal_totalEnergy_layer35;1	Total deposited energy in layer 35
//   KEY: TH1F	ecal_activeEnergy_layer35;1	Deposited energy in active material, in layer 35
//   KEY: TH1F	ecal_sf_layer35;1	SF for layer 35
//   KEY: TH1F	ecal_totalEnergy_layer36;1	Total deposited energy in layer 36
//   KEY: TH1F	ecal_activeEnergy_layer36;1	Deposited energy in active material, in layer 36
//   KEY: TH1F	ecal_sf_layer36;1	SF for layer 36
//   KEY: TH1F	ecal_totalEnergy_layer37;1	Total deposited energy in layer 37
//   KEY: TH1F	ecal_activeEnergy_layer37;1	Deposited energy in active material, in layer 37
//   KEY: TH1F	ecal_sf_layer37;1	SF for layer 37
//   KEY: TH1F	ecal_totalEnergy_layer38;1	Total deposited energy in layer 38
//   KEY: TH1F	ecal_activeEnergy_layer38;1	Deposited energy in active material, in layer 38
//   KEY: TH1F	ecal_sf_layer38;1	SF for layer 38
//   KEY: TH1F	ecal_totalEnergy_layer39;1	Total deposited energy in layer 39
//   KEY: TH1F	ecal_activeEnergy_layer39;1	Deposited energy in active material, in layer 39
//   KEY: TH1F	ecal_sf_layer39;1	SF for layer 39
//   KEY: TH1F	ecal_totalEnergy_layer40;1	Total deposited energy in layer 40
//   KEY: TH1F	ecal_activeEnergy_layer40;1	Deposited energy in active material, in layer 40
//   KEY: TH1F	ecal_sf_layer40;1	SF for layer 40
//   KEY: TH1F	ecal_totalEnergy_layer41;1	Total deposited energy in layer 41
//   KEY: TH1F	ecal_activeEnergy_layer41;1	Deposited energy in active material, in layer 41
//   KEY: TH1F	ecal_sf_layer41;1	SF for layer 41
//   KEY: TH1F	ecal_totalEnergy_layer42;1	Total deposited energy in layer 42
//   KEY: TH1F	ecal_activeEnergy_layer42;1	Deposited energy in active material, in layer 42
//   KEY: TH1F	ecal_sf_layer42;1	SF for layer 42
//   KEY: TH1F	ecal_totalEnergy_layer43;1	Total deposited energy in layer 43
//   KEY: TH1F	ecal_activeEnergy_layer43;1	Deposited energy in active material, in layer 43
//   KEY: TH1F	ecal_sf_layer43;1	SF for layer 43
//   KEY: TH1F	ecal_totalEnergy_layer44;1	Total deposited energy in layer 44
//   KEY: TH1F	ecal_activeEnergy_layer44;1	Deposited energy in active material, in layer 44
//   KEY: TH1F	ecal_sf_layer44;1	SF for layer 44
//   KEY: TH1F	ecal_totalEnergy_layer45;1	Total deposited energy in layer 45
//   KEY: TH1F	ecal_activeEnergy_layer45;1	Deposited energy in active material, in layer 45
//   KEY: TH1F	ecal_sf_layer45;1	SF for layer 45
//   KEY: TH1F	ecal_totalEnergy_layer46;1	Total deposited energy in layer 46
//   KEY: TH1F	ecal_activeEnergy_layer46;1	Deposited energy in active material, in layer 46
//   KEY: TH1F	ecal_sf_layer46;1	SF for layer 46
//   KEY: TH1F	ecal_totalEnergy_layer47;1	Total deposited energy in layer 47
//   KEY: TH1F	ecal_activeEnergy_layer47;1	Deposited energy in active material, in layer 47
//   KEY: TH1F	ecal_sf_layer47;1	SF for layer 47
//   KEY: TH1F	ecal_totalEnergy_layer48;1	Total deposited energy in layer 48
//   KEY: TH1F	ecal_activeEnergy_layer48;1	Deposited energy in active material, in layer 48
//   KEY: TH1F	ecal_sf_layer48;1	SF for layer 48
//   KEY: TH1F	ecal_totalEnergy_layer49;1	Total deposited energy in layer 49
//   KEY: TH1F	ecal_activeEnergy_layer49;1	Deposited energy in active material, in layer 49
//   KEY: TH1F	ecal_sf_layer49;1	SF for layer 49
//   KEY: TH1F	ecal_totalEnergy_layer50;1	Total deposited energy in layer 50
//   KEY: TH1F	ecal_activeEnergy_layer50;1	Deposited energy in active material, in layer 50
//   KEY: TH1F	ecal_sf_layer50;1	SF for layer 50
//   KEY: TH1F	ecal_totalEnergy_layer51;1	Total deposited energy in layer 51
//   KEY: TH1F	ecal_activeEnergy_layer51;1	Deposited energy in active material, in layer 51
//   KEY: TH1F	ecal_sf_layer51;1	SF for layer 51
//   KEY: TH1F	ecal_totalEnergy_layer52;1	Total deposited energy in layer 52
//   KEY: TH1F	ecal_activeEnergy_layer52;1	Deposited energy in active material, in layer 52
//   KEY: TH1F	ecal_sf_layer52;1	SF for layer 52
//   KEY: TH1F	ecal_totalEnergy_layer53;1	Total deposited energy in layer 53
//   KEY: TH1F	ecal_activeEnergy_layer53;1	Deposited energy in active material, in layer 53
//   KEY: TH1F	ecal_sf_layer53;1	SF for layer 53
//   KEY: TH1F	ecal_totalEnergy_layer54;1	Total deposited energy in layer 54
//   KEY: TH1F	ecal_activeEnergy_layer54;1	Deposited energy in active material, in layer 54
//   KEY: TH1F	ecal_sf_layer54;1	SF for layer 54
//   KEY: TH1F	ecal_totalEnergy_layer55;1	Total deposited energy in layer 55
//   KEY: TH1F	ecal_activeEnergy_layer55;1	Deposited energy in active material, in layer 55
//   KEY: TH1F	ecal_sf_layer55;1	SF for layer 55
//   KEY: TH1F	ecal_totalEnergy_layer56;1	Total deposited energy in layer 56
//   KEY: TH1F	ecal_activeEnergy_layer56;1	Deposited energy in active material, in layer 56
//   KEY: TH1F	ecal_sf_layer56;1	SF for layer 56
//   KEY: TH1F	ecal_totalEnergy_layer57;1	Total deposited energy in layer 57
//   KEY: TH1F	ecal_activeEnergy_layer57;1	Deposited energy in active material, in layer 57
//   KEY: TH1F	ecal_sf_layer57;1	SF for layer 57
//   KEY: TH1F	ecal_totalEnergy_layer58;1	Total deposited energy in layer 58
//   KEY: TH1F	ecal_activeEnergy_layer58;1	Deposited energy in active material, in layer 58
//   KEY: TH1F	ecal_sf_layer58;1	SF for layer 58
//   KEY: TH1F	ecal_totalEnergy_layer59;1	Total deposited energy in layer 59
//   KEY: TH1F	ecal_activeEnergy_layer59;1	Deposited energy in active material, in layer 59
//   KEY: TH1F	ecal_sf_layer59;1	SF for layer 59
//   KEY: TH1F	ecal_totalEnergy_layer60;1	Total deposited energy in layer 60
//   KEY: TH1F	ecal_activeEnergy_layer60;1	Deposited energy in active material, in layer 60
//   KEY: TH1F	ecal_sf_layer60;1	SF for layer 60
//   KEY: TH1F	ecal_totalEnergy_layer61;1	Total deposited energy in layer 61
//   KEY: TH1F	ecal_activeEnergy_layer61;1	Deposited energy in active material, in layer 61
//   KEY: TH1F	ecal_sf_layer61;1	SF for layer 61
//   KEY: TH1F	ecal_totalEnergy_layer62;1	Total deposited energy in layer 62
//   KEY: TH1F	ecal_activeEnergy_layer62;1	Deposited energy in active material, in layer 62
//   KEY: TH1F	ecal_sf_layer62;1	SF for layer 62
//   KEY: TH1F	ecal_totalEnergy_layer63;1	Total deposited energy in layer 63
//   KEY: TH1F	ecal_activeEnergy_layer63;1	Deposited energy in active material, in layer 63
//   KEY: TH1F	ecal_sf_layer63;1	SF for layer 63
//   KEY: TH1F	ecal_totalEnergy_layer64;1	Total deposited energy in layer 64
//   KEY: TH1F	ecal_activeEnergy_layer64;1	Deposited energy in active material, in layer 64
//   KEY: TH1F	ecal_sf_layer64;1	SF for layer 64
//   KEY: TH1F	ecal_totalEnergy_layer65;1	Total deposited energy in layer 65
//   KEY: TH1F	ecal_activeEnergy_layer65;1	Deposited energy in active material, in layer 65
//   KEY: TH1F	ecal_sf_layer65;1	SF for layer 65
//   KEY: TH1F	ecal_totalEnergy_layer66;1	Total deposited energy in layer 66
//   KEY: TH1F	ecal_activeEnergy_layer66;1	Deposited energy in active material, in layer 66
//   KEY: TH1F	ecal_sf_layer66;1	SF for layer 66
//   KEY: TH1F	ecal_totalEnergy_layer67;1	Total deposited energy in layer 67
//   KEY: TH1F	ecal_activeEnergy_layer67;1	Deposited energy in active material, in layer 67
//   KEY: TH1F	ecal_sf_layer67;1	SF for layer 67
//   KEY: TH1F	ecal_totalEnergy_layer68;1	Total deposited energy in layer 68
//   KEY: TH1F	ecal_activeEnergy_layer68;1	Deposited energy in active material, in layer 68
//   KEY: TH1F	ecal_sf_layer68;1	SF for layer 68
//   KEY: TH1F	ecal_totalEnergy_layer69;1	Total deposited energy in layer 69
//   KEY: TH1F	ecal_activeEnergy_layer69;1	Deposited energy in active material, in layer 69
//   KEY: TH1F	ecal_sf_layer69;1	SF for layer 69
//   KEY: TH1F	ecal_totalEnergy_layer70;1	Total deposited energy in layer 70
//   KEY: TH1F	ecal_activeEnergy_layer70;1	Deposited energy in active material, in layer 70
//   KEY: TH1F	ecal_sf_layer70;1	SF for layer 70
//   KEY: TH1F	ecal_totalEnergy_layer71;1	Total deposited energy in layer 71
//   KEY: TH1F	ecal_activeEnergy_layer71;1	Deposited energy in active material, in layer 71
//   KEY: TH1F	ecal_sf_layer71;1	SF for layer 71
//   KEY: TH1F	ecal_totalEnergy_layer72;1	Total deposited energy in layer 72
//   KEY: TH1F	ecal_activeEnergy_layer72;1	Deposited energy in active material, in layer 72
//   KEY: TH1F	ecal_sf_layer72;1	SF for layer 72
//   KEY: TH1F	ecal_totalEnergy_layer73;1	Total deposited energy in layer 73
//   KEY: TH1F	ecal_activeEnergy_layer73;1	Deposited energy in active material, in layer 73
//   KEY: TH1F	ecal_sf_layer73;1	SF for layer 73
//   KEY: TH1F	ecal_totalEnergy_layer74;1	Total deposited energy in layer 74
//   KEY: TH1F	ecal_activeEnergy_layer74;1	Deposited energy in active material, in layer 74
//   KEY: TH1F	ecal_sf_layer74;1	SF for layer 74
//   KEY: TH1F	ecal_totalEnergy_layer75;1	Total deposited energy in layer 75
//   KEY: TH1F	ecal_activeEnergy_layer75;1	Deposited energy in active material, in layer 75
//   KEY: TH1F	ecal_sf_layer75;1	SF for layer 75
//   KEY: TH1F	ecal_totalEnergy_layer76;1	Total deposited energy in layer 76
//   KEY: TH1F	ecal_activeEnergy_layer76;1	Deposited energy in active material, in layer 76
//   KEY: TH1F	ecal_sf_layer76;1	SF for layer 76
//   KEY: TH1F	ecal_totalEnergy_layer77;1	Total deposited energy in layer 77
//   KEY: TH1F	ecal_activeEnergy_layer77;1	Deposited energy in active material, in layer 77
//   KEY: TH1F	ecal_sf_layer77;1	SF for layer 77
//   KEY: TH1F	ecal_totalEnergy_layer78;1	Total deposited energy in layer 78
//   KEY: TH1F	ecal_activeEnergy_layer78;1	Deposited energy in active material, in layer 78
//   KEY: TH1F	ecal_sf_layer78;1	SF for layer 78
//   KEY: TH1F	ecal_totalEnergy_layer79;1	Total deposited energy in layer 79
//   KEY: TH1F	ecal_activeEnergy_layer79;1	Deposited energy in active material, in layer 79
//   KEY: TH1F	ecal_sf_layer79;1	SF for layer 79
//   KEY: TH1F	ecal_totalEnergy_layer80;1	Total deposited energy in layer 80
//   KEY: TH1F	ecal_activeEnergy_layer80;1	Deposited energy in active material, in layer 80
//   KEY: TH1F	ecal_sf_layer80;1	SF for layer 80
//   KEY: TH1F	ecal_totalEnergy_layer81;1	Total deposited energy in layer 81
//   KEY: TH1F	ecal_activeEnergy_layer81;1	Deposited energy in active material, in layer 81
//   KEY: TH1F	ecal_sf_layer81;1	SF for layer 81
//   KEY: TH1F	ecal_totalEnergy_layer82;1	Total deposited energy in layer 82
//   KEY: TH1F	ecal_activeEnergy_layer82;1	Deposited energy in active material, in layer 82
//   KEY: TH1F	ecal_sf_layer82;1	SF for layer 82
//   KEY: TH1F	ecal_totalEnergy_layer83;1	Total deposited energy in layer 83
//   KEY: TH1F	ecal_activeEnergy_layer83;1	Deposited energy in active material, in layer 83
//   KEY: TH1F	ecal_sf_layer83;1	SF for layer 83
//   KEY: TH1F	ecal_totalEnergy_layer84;1	Total deposited energy in layer 84
//   KEY: TH1F	ecal_activeEnergy_layer84;1	Deposited energy in active material, in layer 84
//   KEY: TH1F	ecal_sf_layer84;1	SF for layer 84
//   KEY: TH1F	ecal_totalEnergy_layer85;1	Total deposited energy in layer 85
//   KEY: TH1F	ecal_activeEnergy_layer85;1	Deposited energy in active material, in layer 85
//   KEY: TH1F	ecal_sf_layer85;1	SF for layer 85
//   KEY: TH1F	ecal_totalEnergy_layer86;1	Total deposited energy in layer 86
//   KEY: TH1F	ecal_activeEnergy_layer86;1	Deposited energy in active material, in layer 86
//   KEY: TH1F	ecal_sf_layer86;1	SF for layer 86
//   KEY: TH1F	ecal_totalEnergy_layer87;1	Total deposited energy in layer 87
//   KEY: TH1F	ecal_activeEnergy_layer87;1	Deposited energy in active material, in layer 87
//   KEY: TH1F	ecal_sf_layer87;1	SF for layer 87
//   KEY: TH1F	ecal_totalEnergy_layer88;1	Total deposited energy in layer 88
//   KEY: TH1F	ecal_activeEnergy_layer88;1	Deposited energy in active material, in layer 88
//   KEY: TH1F	ecal_sf_layer88;1	SF for layer 88
//   KEY: TH1F	ecal_totalEnergy_layer89;1	Total deposited energy in layer 89
//   KEY: TH1F	ecal_activeEnergy_layer89;1	Deposited energy in active material, in layer 89
//   KEY: TH1F	ecal_sf_layer89;1	SF for layer 89
//   KEY: TH1F	ecal_totalEnergy;1	Total deposited energy
//   KEY: TH1F	ecal_active;1	Deposited energy in active material
//   KEY: TH1F	ecal_sf;1	Sampling fraction

// %%
// Example histogram 
TH1F *h1=(TH1F*)f->Get("ecal_sf_layer20");
h1->Draw();
c1->Draw();
double mean = h1->GetMean();
std::cout << mean;
c1->SaveAs("SFlayer20.pdf")
// Out:
// 0.126436
// Info in <TCanvas::Print>: pdf file SFlayer20.pdf has been created

// %%
int nhists = 90;

// open text file to write sampling fraction values to 
ofstream MyFile("SamplingFraction_90layers.txt");

// loop over all histograms 
for(Int_t i=0; i<nhists; i++){
    
    char buffer[100];
    int retVal;
    int hist = i;
    // sprintf to write formatted string to character string buffer 
    retVal = sprintf(buffer, "ecal_sf_layer%d", hist);
    
    // get the histogram 
    TH1F *h=(TH1F*)f->Get(buffer);
    // extract the mean 
    double mean = h->GetMean();
    
    // write mean to text file
    MyFile << "[" << mean << "]*1 + ";
}

MyFile.close();
